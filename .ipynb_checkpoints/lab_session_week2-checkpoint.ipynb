#         52, 296, 155, 181, 295, 242, 350, 260, 396, 200, 346, 217,  48,
#        179, 229, 251, 394, 401, 483, 455, 365, 204, 526,  79, 479, 330,
#        372, 429,  24, 575, 235, 564, 595, 245, 224, 434, 100, 118, 287,
#        188, 201,  11, 172, 570, 418, 492,  30, 437, 561,  92, 216,  47,
#        399, 125, 290, 525, 419,  14, 422, 535, 367, 364, 359, 456, 389,
#        537, 207, 321, 458, 336, 115, 297,   8, 508, 107, 319, 131, 491,
#        426,  70, 608, 215, 605, 189, 407, 351,  12, 156, 415, 498, 142,
#        252, 481, 116, 586, 518, 135, 148, 477, 523,  84, 324, 409,  63,
#        499, 578, 402, 522, 184, 210, 607, 340, 593, 527, 390, 165,  50,
#        410, 382, 445, 257, 528, 193,  18, 137,  91, 436, 502,  93])

# %% [markdown]
# #### Answer Question 2
#
# ##### What does the 'NaN' mean in this context?
# *NaN* normally means there is no data for a cell in data frame. In this context, it means there is no information that the user rate the movie.

# %% [markdown]
# Now we will convert our data structure into a form that is appropriate for processing. We will convert the `Y_with_NaNs` dataframe into a new dataframe which contains the user, the movie, and the rating using the following code

# %%
p_list_ratings = np.concatenate(list_ratings_each_user).ravel()
p_list_ratings_original = p_list_ratings.tolist()
mean_ratings_train = np.mean(p_list_ratings)
p_list_ratings =  p_list_ratings - mean_ratings_train # remove the mean
p_list_movies = np.concatenate(list_movies_each_user).ravel().tolist()
p_list_users = list_users.tolist()
Y = pd.DataFrame({'users': p_list_users, 'movies': p_list_movies, 'ratingsorig': p_list_ratings_original,'ratings':p_list_ratings.tolist()})
print(Y)
# Out:
#       users  movies  ratingsorig   ratings
# 0     130.0       1          3.0 -0.590376
# 1     130.0     110          5.0  1.409624
# 2     130.0     150          4.0  0.409624
# 3     130.0     153          4.0  0.409624
# 4     130.0     161          4.0  0.409624
# 5     130.0     165          4.0  0.409624
# 6     130.0     185          3.0 -0.590376
# 7     130.0     208          3.0 -0.590376
# 8     130.0     225          5.0  1.409624
# 9     130.0     231          4.0  0.409624
# 10    130.0     253          4.0  0.409624
# 11    130.0     292          5.0  1.409624
# 12    130.0     296          4.0  0.409624
# 13    130.0     300          3.0 -0.590376
# 14    130.0     316          3.0 -0.590376
# 15    130.0     317          3.0 -0.590376
# 16    130.0     318          5.0  1.409624
# 17    130.0     329          3.0 -0.590376
# 18    130.0     339          4.0  0.409624
# 19    130.0     344          4.0  0.409624
# 20    130.0     349          2.0 -1.590376
# 21    130.0     380          3.0 -0.590376
# 22    130.0     410          4.0  0.409624
# 23    130.0     434          3.0 -0.590376
# 24    130.0     588          2.0 -1.590376
# 25    130.0     590          3.0 -0.590376
# 26    130.0     592          3.0 -0.590376
# 27    130.0     595          2.0 -1.590376
# 28    220.0       1          5.0  1.409624
# 29    220.0       6          3.5 -0.090376
# ...     ...     ...          ...       ...
# 2017   70.0    8949          5.0  1.409624
# 2018   70.0   37741          4.5  0.909624
# 2019   70.0   55820          4.0  0.409624
# 2020   70.0   63082          5.0  1.409624
# 2021   70.0   69757          4.0  0.409624
# 2022   70.0   72011          4.5  0.909624
# 2023   70.0   89492          4.5  0.909624
# 2024   70.0   91077          4.0  0.409624
# 2025  120.0       5          4.0  0.409624
# 2026  120.0      12          3.0 -0.590376
# 2027  120.0      32          3.0 -0.590376
# 2028  120.0      52          3.0 -0.590376
# 2029  120.0     141          3.0 -0.590376
# 2030  120.0     260          5.0  1.409624
# 2031  120.0     608          5.0  1.409624
# 2032  120.0     631          3.0 -0.590376
# 2033  120.0     648          3.0 -0.590376
# 2034  120.0     653          3.0 -0.590376
# 2035  120.0     733          4.0  0.409624
# 2036  120.0     736          3.0 -0.590376
# 2037  120.0     743          3.0 -0.590376
# 2038  120.0     765          3.0 -0.590376
# 2039  120.0     780          2.0 -1.590376
# 2040  120.0     783          3.0 -0.590376
# 2041  120.0     802          4.0  0.409624
# 2042  120.0     852          2.0 -1.590376
# 2043  120.0     858          5.0  1.409624
# 2044  120.0    1073          2.0 -1.590376
# 2045  120.0    1210          5.0  1.409624
# 2046  120.0    1367          4.0  0.409624
#
# [2047 rows x 4 columns]

# %% [markdown]
# ### Assignment Question 3
#
# The dataframes `Y_with_NaNs` and `Y` contain the same information but organised in a different way. Explain what is the difference. We have also included two columns for ratings in dataframe `Y`, `ratingsorig` and `ratings`. Explain
# the difference.
#
# *10 marks*

# %% [markdown]
# #### Question 3 Answer
#
# ##### What is the difference?
# Y_with_NaNs created the blank data frame before put the datas and indexes inside, while Y put datas and indexes as it created table. As a result, Y_with_NaNs can contains "NaN"s data.
#
# ##### We have also included two columns for ratings in dataframe Y, ratingsorig and ratings. Explain the difference.
# Ratingsorig is the rating that user rate the movie. Rating is the Ratingsorig for 1 user minus mean of Ratingsorig of total users.

# %% [markdown]
# ## Measuring Similarity
#
# We now need a measure for determining the similarity between the item and the user: how close the user is sitting to the item in the rooom if you like. We are going to use the inner product between the vector representing the item and the vector representing the user.
#
# An inner product (or [dot product](http://en.wikipedia.org/wiki/Dot_product)) between two vectors $\mathbf{a}$ and $\mathbf{b}$ is written as $\mathbf{a}\cdot\mathbf{b}$. Or in vector notation we sometimes write it as $\mathbf{a}^\top\mathbf{b}$. An inner product is simply the sume of the products of each element of the vector,
# $$
# \mathbf{a}^\top\mathbf{b} = \sum_{i} a_i b_i
# $$
# The inner product can be seen as a measure of similarity. The inner product gives us the cosine of the angle between the two vectors multiplied by their length. The smaller the angle between two vectors the larger the inner product.
# $$
# \mathbf{a}^\top\mathbf{b} = |\mathbf{a}||\mathbf{b}| \cos(\theta)
# $$
# where $\theta$ is the angle between two vectors and $|\mathbf{a}|$ and $|\mathbf{b}|$ are the respective lengths of the two vectors.
#
# Since we want each user to be sitting near each item, then we want the inner product to be large for any two items which are rated highly by that user. We can do this by trying to force the inner product $\mathbf{u}_i^\top\mathbf{v}_j$ to be similar to the rating given by the user, $y_{i,j}$. To ensure this we will use a least squares objective function for all user ratings.

# %% [markdown]
# ## Objective Function
#
# The error function (or objective function, or cost function) we will choose is known as 'sum of squares', we will aim to minimize the sum of squared squared error between the inner product of $\mathbf{u}_i$ and $\mathbf{v}_i$ and the observed score for the user/item pairing, given by $y_{i, j}$.
#
# The total objective function can be written as
# $$
# E(\mathbf{U}, \mathbf{V}) = \sum_{i,j} s_{i,j} (y_{i,j} - \mathbf{u}_i^\top \mathbf{v}_j)^2
# $$
# where $s_{i,j}$ is an *indicator* variable that is 1 if user $i$ has rated item $j$ and is zero otherwise. Here $\mathbf{U}$ is the matrix made up of all the vectors $\mathbf{u}$,
# $$
# \mathbf{U} = \begin{bmatrix} \mathbf{u}_1 \dots \mathbf{u}_n\end{bmatrix}^\top
# $$
# where we note that $i$th *row* of $\mathbf{U}$ contains the vector associated with the $i$th user and $n$ is the total number of users. This form of matrix is known as a *design matrix*. Similarly, we define the matrix
# $$
# \mathbf{V} = \begin{bmatrix} \mathbf{v}_1 \dots \mathbf{v}_m\end{bmatrix}^\top
# $$
# where again the $j$th row of $\mathbf{V}$ contains the vector associated with the $j$th item and $m$ is the total number of items in the data set.
#
# ## Objective Optimization
#
# The idea is to mimimize this objective. A standard, simple, technique for minimizing an objective is *gradient descent* or *steepest descent*. In gradient descent we simply choose to update each parameter in the model by subtracting a multiple of the objective function's gradient with respect to the parameters. So for a parameter $u_{i,j}$ from the matrix $\mathbf{U}$ we would have an update as follows:
# $$
# u_{k,\ell} \leftarrow u_{k,\ell} - \eta \frac{\text{d} E(\mathbf{U}, \mathbf{V})}{\text{d}u_{k,\ell}}
# $$
# where $\eta$ (which is pronounced *eta* in English) is a Greek letter representing the *learning rate*.
#
# We can compute *the gradient of the objective function* with respect to $u_{k,\ell}$ as
# $$
# \frac{\text{d}E(\mathbf{U}, \mathbf{V})}{\text{d}u_{k,\ell}} = -2 \sum_j s_{k,j}v_{j,\ell}(y_{k, j} - \mathbf{u}_k^\top\mathbf{v}_{j}).
# $$
# Similarly each parameter $v_{i,j}$ needs to be updated according to its gradient.

# %% [markdown]
# ### Assignment Question 4
#
# What is the *gradient of the objective function* with respect to $v_{k, \ell}$? Write your answer in the box below, and explain which differentiation techniques you used to get there. You will be expected to justify your answer in class by oral questioning.
#
# *15 marks*

# %% [markdown]
# #### Question 4 Answer
#
# #### Finding the gradient of the objective function with respect to $v_{k,\ell}$
# Using $\frac{dE(U,V)}{dv_{k,\ell}}$ instead of $\frac{\text{d}E(\mathbf{U}, \mathbf{V})}{\text{d}u_{k,\ell}}$
# $$
# \begin{split}
# Gof(v_{k,\ell}) &= \frac{\text{d}E(\mathbf{U}, \mathbf{V})}{\text{d}v_{k,\ell}}\\
# &=\frac{\text{d}}{\text{d}v_{k,\ell}}\sum_{i,j} s_{i,j} (y_{i,j} - \mathbf{u}_i^\top \mathbf{v}_j)^2\\
# &= -2 \sum_i s_{i,k}u_{i,\ell}(y_{i, k} - \mathbf{u}_i^\top\mathbf{v}_{k})
# \end{split}
# $$

# %%
# Question 4 Code Answer

# %% [markdown]
# ## Steepest Descent Algorithm
#
# In the steepest descent algorithm we aim to minimize the objective function by subtacting the gradient of the objective function from the parameters.
#
# ### Initialisation
#
# To start with though, we need initial values for the matrix $\mathbf{U}$ and the matrix $\mathbf{V}$. Let's create them as `pandas` data frames and initialise them randomly with small values.

# %%
q = 2 # the dimension of our map of the 'library'
learn_rate = 0.01
U = pd.DataFrame(np.random.normal(size=(nUsersInExample, q))*0.001, index=my_batch_users) #users vector
V = pd.DataFrame(np.random.normal(size=(n_movies, q))*0.001, index=indexes_unique_movies) #movies vector

#print(Y)
#rint(Y.iloc[0])
#user = Y.iloc[0].users
#print(Y.iloc[0].users)
#film = Y.iloc[0].movies
#print("U is \n" , U)
#testpd = pd.DataFrame(np.zeros((U.shape)), index=U.index)
#print("testpd is ",testpd.loc[user])
#print("pd u is \n",pd.DataFrame(np.zeros((U.shape)), index=U.index))
#print("U.loc[user]\n" , U.loc[user]) 
#print("V is \n", V)
#print("V.loc[user]\n" ,V.loc[film])
#test = Y.iloc[0]
#print("test\n",test)
#print(test['users'])
#print("test[ratings] = ",test['ratings'])
#print("My batch users (All user id) = \n",my_batch_users)
#print("Idexes unique movies (All movies id)\n",indexes_unique_movies)

# %% [markdown]
# Now that we have the initial values set, we can start the optimization. First we define a function for the gradient of the objective and the objective function itself.

# %%
def objective_gradient(Y, U, V):
    gU = pd.DataFrame(np.zeros((U.shape)), index=U.index)
    gV = pd.DataFrame(np.zeros((V.shape)), index=V.index)
    obj = 0.
    nrows = Y.shape[0]
    for i in range(nrows):
        row = Y.iloc[i] #Getting the user i
        user = row['users'] #Getting 'users' information
        film = row['movies'] #Getting 'movies' information
        rating = row['ratings'] #Getting 'ratings' information
        prediction = np.dot(U.loc[user], V.loc[film]) # U.V
        #print(U.loc[user])
        #print(V.loc[film])
        diff = prediction - rating # v^Tu - y
        obj += diff*diff
        #print("Old gU\n",gU)
        #print("Gradiant U at ",i," is ", 2*diff*V.loc[film])
        gU.loc[user] += 2*diff*V.loc[film]
        #print("New gU\n",2*diff*V.loc[film])
        gV.loc[film] += 2*diff*U.loc[user]
        #print(2*diff*U.loc[user])
        #print(error)
   # print(gU)
    return obj, gU, gV
iterations = 10
for i in range(iterations):
    print("Old U \n",U)
    obj, gU, gV = objective_gradient(Y, U, V)
    
    print("Iteration", i, "Objective function: ", obj)
    U -= learn_rate*gU
    #print("gU\n",gU)
    #print("learn_rate*gU\n",learn_rate*gU)
    V -= learn_rate*gV    
print(Y)
# Out:
# Old U
#              0         1
# 130 -0.001481 -0.000910
# 220 -0.000545  0.000111
# 341 -0.001426 -0.001347
# 480 -0.000934  0.001778
# 34   0.000219  0.000061
# 346 -0.000642  0.000661
# 534 -0.000118  0.000541
# 86  -0.001189 -0.000763
# 70   0.000717 -0.000035
# 120  0.001328 -0.000289
# Iteration 0 Objective function:  1903.2804442333813
# Old U
#              0         1
# 130 -0.001488 -0.000822
# 220 -0.000670  0.000575
# 341 -0.001462 -0.001395
# 480 -0.000342  0.001973
# 34  -0.000113  0.000212
# 346 -0.000421  0.000463
# 534 -0.000516  0.000638
# 86  -0.001120 -0.000739
# 70   0.000859  0.000028
# 120  0.001276 -0.000318
# Iteration 1 Objective function:  1903.28016289121
# Old U
#              0         1
# 130 -0.001508 -0.000738
# 220 -0.000862  0.001069
# 341 -0.001511 -0.001458
# 480 -0.000125  0.002881
# 34  -0.000436  0.000375
# 346 -0.000223  0.000289
# 534 -0.000931  0.000785
# 86  -0.001067 -0.000720
# 70   0.001009  0.000100
# 120  0.001231 -0.000345
# Iteration 2 Objective function:  1903.2797333930816
# Old U
#              0         1
# 130 -0.001540 -0.000656
# 220 -0.001131  0.001644
# 341 -0.001573 -0.001536
# 480 -0.000045  0.004586
# 34  -0.000764  0.000562
# 346 -0.000037  0.000135
# 534 -0.001409  0.000996
# 86  -0.001029 -0.000705
# 70   0.001174  0.000185
# 120  0.001195 -0.000369
# Iteration 3 Objective function:  1903.2787397205548
# Old U
#              0         1
# 130 -0.001582 -0.000574
# 220 -0.001502  0.002361
# 341 -0.001650 -0.001631
# 480 -0.000017  0.007458
# 34  -0.001117  0.000787
# 346  0.000145 -0.000004
# 534 -0.001994  0.001291
# 86  -0.001009 -0.000690
# 70   0.001355  0.000292
# 120  0.001166 -0.000385
# Iteration 4 Objective function:  1903.2762523681624
# Old U
#              0         1
# 130 -0.001634 -0.000487
# 220 -0.002007  0.003297
# 341 -0.001743 -0.001745
# 480 -0.000009  0.012186
# 34  -0.001514  0.001072
# 346  0.000328 -0.000126
# 534 -0.002739  0.001694
# 86  -0.001009 -0.000670
# 70   0.001557  0.000436
# 120  0.001145 -0.000389
# Iteration 5 Objective function:  1903.269854792163
# Old U
#              0         1
# 130 -0.001694 -0.000389
# 220 -0.002690  0.004558
# 341 -0.001854 -0.001882
# 480 -0.000012  0.019930
# 34  -0.001977  0.001448
# 346  0.000521 -0.000230
# 534 -0.003711  0.002234
# 86  -0.001032 -0.000641
# 70   0.001780  0.000638
# 120  0.001129 -0.000372
# Iteration 6 Objective function:  1903.253169228443
# Old U
#              0         1
# 130 -0.001761 -0.000269
# 220 -0.003614  0.006290
# 341 -0.001983 -0.002049
# 480 -0.000026  0.032598
# 34  -0.002529  0.001960
# 346  0.000730 -0.000306
# 534 -0.004993  0.002950
# 86  -0.001082 -0.000594
# 70   0.002027  0.000934
# 120  0.001118 -0.000319
# Iteration 7 Objective function:  1903.2092905369366
# Old U
#              0         1
# 130 -0.001835 -0.000109
# 220 -0.004861  0.008702
# 341 -0.002133 -0.002255
# 480 -0.000056  0.053311
# 34  -0.003196  0.002676
# 346  0.000963 -0.000335
# 534 -0.006695  0.003888
# 86  -0.001166 -0.000518
# 70   0.002297  0.001376
# 120  0.001109 -0.000207
# Iteration 8 Objective function:  1903.0933036013996
# Old U
#              0         1
# 130 -0.001915  0.000120
# 2032  120.0     631          3.0 -0.590376   -0.061378        0.528999
# 2033  120.0     648          3.0 -0.590376   -0.102236        0.488140
# 2034  120.0     653          3.0 -0.590376   -0.218153        0.372223
# 2035  120.0     733          4.0  0.409624    0.032893        0.376731
# 2036  120.0     736          3.0 -0.590376   -0.066721        0.523655
# 2037  120.0     743          3.0 -0.590376   -0.131165        0.459211
# 2038  120.0     765          3.0 -0.590376   -0.061506        0.528870
# 2039  120.0     780          2.0 -1.590376   -0.058468        1.531908
# 2040  120.0     783          3.0 -0.590376   -0.024820        0.565556
# 2041  120.0     802          4.0  0.409624   -0.067975        0.477598
# 2042  120.0     852          2.0 -1.590376   -0.167041        1.423335
# 2043  120.0     858          5.0  1.409624    0.286580        1.123044
# 2044  120.0    1073          2.0 -1.590376   -0.050177        1.540200
# 2045  120.0    1210          5.0  1.409624    0.125830        1.283794
# 2046  120.0    1367          4.0  0.409624    0.043020        0.366604
#
# [2047 rows x 6 columns]

# %% [markdown]
# $Prediction = \vec{U_{2x1}}\cdot \vec{V_{2x1}}$
#
# $Obj = \sum_1^{nrows}(Prediction_i-rating_i)^2$

# %% [markdown]
# Now we can write our simple optimisation route. This allows us to observe the objective function as the optimization proceeds.

# %%
iterations = 30
for i in range(iterations):
    obj, gU, gV = objective_gradient(Y, U, V)
    print("Iteration", i, "Objective function: ", obj)
    U -= learn_rate*gU    
    V -= learn_rate*gV    
print(Y)
# Out:
# Iteration 0 Objective function:  1903.2798105416691
# Iteration 1 Objective function:  1903.2793175060178
# Iteration 2 Objective function:  1903.278358989999
# Iteration 3 Objective function:  1903.2763566839826
# Iteration 4 Objective function:  1903.2719192595264
# Iteration 5 Objective function:  1903.261585321891
# Iteration 6 Objective function:  1903.2365468138485
# Iteration 7 Objective function:  1903.1740355745071
# Iteration 8 Objective function:  1903.0145663818655
# Iteration 9 Objective function:  1902.601639988529
# Iteration 10 Objective function:  1901.5218653899778
# Iteration 11 Objective function:  1898.6821680656046
# Iteration 12 Objective function:  1891.2030490818822
# Iteration 13 Objective function:  1871.6067030546685
# Iteration 14 Objective function:  1821.2689700731096
# Iteration 15 Objective function:  1699.075843725791
# Iteration 16 Objective function:  1444.2324538534122
# Iteration 17 Objective function:  1086.262247139125
# Iteration 18 Objective function:  898.6617745886407
# Iteration 19 Objective function:  887.3859140192949
# Iteration 20 Objective function:  880.5140974146175
# Iteration 21 Objective function:  870.9022918759686
# Iteration 22 Objective function:  856.89498291726
# Iteration 23 Objective function:  836.5495641824573
# Iteration 24 Objective function:  807.5467933496072
# Iteration 25 Objective function:  767.6741268998776
# Iteration 26 Objective function:  716.0646723775897
# Iteration 27 Objective function:  655.1753071351083
# Iteration 28 Objective function:  592.1785462309765
# Iteration 29 Objective function:  536.8868857331652
#       users  movies  ratingsorig   ratings
# 0     130.0       1          3.0 -0.590376
# 1     130.0     110          5.0  1.409624
# 2     130.0     150          4.0  0.409624
# 3     130.0     153          4.0  0.409624
# 4     130.0     161          4.0  0.409624
# 5     130.0     165          4.0  0.409624
# 6     130.0     185          3.0 -0.590376
# 7     130.0     208          3.0 -0.590376
# 8     130.0     225          5.0  1.409624
# 9     130.0     231          4.0  0.409624
# 10    130.0     253          4.0  0.409624
# 11    130.0     292          5.0  1.409624
# 12    130.0     296          4.0  0.409624
# 13    130.0     300          3.0 -0.590376
# 14    130.0     316          3.0 -0.590376
# 15    130.0     317          3.0 -0.590376
# 16    130.0     318          5.0  1.409624
# 17    130.0     329          3.0 -0.590376
# 18    130.0     339          4.0  0.409624
# 19    130.0     344          4.0  0.409624
# 20    130.0     349          2.0 -1.590376
# 21    130.0     380          3.0 -0.590376
# 22    130.0     410          4.0  0.409624
# 23    130.0     434          3.0 -0.590376
# 24    130.0     588          2.0 -1.590376
# 25    130.0     590          3.0 -0.590376
# 26    130.0     592          3.0 -0.590376
# 27    130.0     595          2.0 -1.590376
# 28    220.0       1          5.0  1.409624
# 29    220.0       6          3.5 -0.090376
# ...     ...     ...          ...       ...
# 2017   70.0    8949          5.0  1.409624
# 2018   70.0   37741          4.5  0.909624
# 2019   70.0   55820          4.0  0.409624
# 2020   70.0   63082          5.0  1.409624
# 2021   70.0   69757          4.0  0.409624
# 2022   70.0   72011          4.5  0.909624
# 2023   70.0   89492          4.5  0.909624
# 2024   70.0   91077          4.0  0.409624
# 2025  120.0       5          4.0  0.409624
# 2026  120.0      12          3.0 -0.590376
# 2027  120.0      32          3.0 -0.590376
# 2028  120.0      52          3.0 -0.590376
# 2029  120.0     141          3.0 -0.590376
# 2030  120.0     260          5.0  1.409624
# 2031  120.0     608          5.0  1.409624
# 2032  120.0     631          3.0 -0.590376
# 2033  120.0     648          3.0 -0.590376
# 2034  120.0     653          3.0 -0.590376
# 2035  120.0     733          4.0  0.409624
# 2036  120.0     736          3.0 -0.590376
# 2037  120.0     743          3.0 -0.590376
# 2038  120.0     765          3.0 -0.590376
# 2039  120.0     780          2.0 -1.590376
# 2040  120.0     783          3.0 -0.590376
# 2041  120.0     802          4.0  0.409624
# 2042  120.0     852          2.0 -1.590376
# 2043  120.0     858          5.0  1.409624
# 2044  120.0    1073          2.0 -1.590376
# 2045  120.0    1210          5.0  1.409624
# 2046  120.0    1367          4.0  0.409624
#
# [2047 rows x 4 columns]

# %% [markdown]
# ### Assignment Question 5
#
# What happens as you increase the number of iterations? What happens if you increase the learning rate?
#
# *10 marks*

# %% [markdown]
# #### Question 5 Answer
#
# ##### What happens as you increase the number of iterations?
# The number of loops is increased and obj is significantly reduced.
# #### *What happens if you increase the learning rate?*
# More learning rate makes greater reducing in each iterations, but if it's too big, the objective result could be error (increase objective result).

# %%
# Question 5 Code Answer
learn_rate = 0.02
U = pd.DataFrame(np.random.normal(size=(nUsersInExample, q))*0.001, index=my_batch_users) #users vector
V = pd.DataFrame(np.random.normal(size=(n_movies, q))*0.001, index=indexes_unique_movies) #movies vector

iterations = 50
for i in range(iterations):
    obj, gU, gV = objective_gradient(Y, U, V)
    print("Iteration", i, "Objective function: ", obj)
    U -= learn_rate*gU    
    V -= learn_rate*gV    
print(Y)
# Out:
# Iteration 0 Objective function:  1903.280653253389
# Iteration 1 Objective function:  1903.2801906399397
# Iteration 2 Objective function:  1903.2796424761552
# Iteration 3 Objective function:  1903.2783139877115
# Iteration 4 Objective function:  1903.2746155224033
# Iteration 5 Objective function:  1903.2635158039684
# Iteration 6 Objective function:  1903.2273412913487
# Iteration 7 Objective function:  1903.0975309644105
# Iteration 8 Objective function:  1902.5829026910078
# Iteration 9 Objective function:  1900.3571858279824
# Iteration 10 Objective function:  1890.1117076975727
# Iteration 11 Objective function:  1841.715998762793
# Iteration 12 Objective function:  1627.3967792338792
# Iteration 13 Objective function:  1032.2355136283882
# Iteration 14 Objective function:  984.4148051448633
# Iteration 15 Objective function:  1159.3543511961686
# Iteration 16 Objective function:  839.8076864186991
# 27    130.0     595          2.0 -1.590376   -0.055007        1.535370
# 28    220.0       1          5.0  1.409624    0.600151        0.809473
# 29    220.0       6          3.5 -0.090376   -0.058093        0.032283
# ...     ...     ...          ...       ...         ...             ...
# 2017   70.0    8949          5.0  1.409624   -0.156867        1.566491
# 2018   70.0   37741          4.5  0.909624    0.438523        0.471100
# 2019   70.0   55820          4.0  0.409624    0.471874        0.062250
# 2020   70.0   63082          5.0  1.409624    0.856872        0.552752
# 2021   70.0   69757          4.0  0.409624    0.253184        0.156440
# 2022   70.0   72011          4.5  0.909624    0.563019        0.346605
# 2023   70.0   89492          4.5  0.909624    0.564795        0.344829
# 2024   70.0   91077          4.0  0.409624    0.255644        0.153980
# 2025  120.0       5          4.0  0.409624    0.041659        0.367964
# 2026  120.0      12          3.0 -0.590376   -0.062195        0.528181
# 2027  120.0      32          3.0 -0.590376    0.105179        0.695556
# 2028  120.0      52          3.0 -0.590376   -0.062327        0.528049
# 2029  120.0     141          3.0 -0.590376   -0.062111        0.528265
# 2030  120.0     260          5.0  1.409624    0.219444        1.190180
# 2031  120.0     608          5.0  1.409624    0.164234        1.245390
# 2032  120.0     631          3.0 -0.590376   -0.061378        0.528999
# 2033  120.0     648          3.0 -0.590376   -0.102236        0.488140
# 2034  120.0     653          3.0 -0.590376   -0.218153        0.372223
# 2035  120.0     733          4.0  0.409624    0.032893        0.376731
# 2036  120.0     736          3.0 -0.590376   -0.066721        0.523655
# 2037  120.0     743          3.0 -0.590376   -0.131165        0.459211
# 2038  120.0     765          3.0 -0.590376   -0.061506        0.528870
# 2039  120.0     780          2.0 -1.590376   -0.058468        1.531908
# 2040  120.0     783          3.0 -0.590376   -0.024820        0.565556
# 2041  120.0     802          4.0  0.409624   -0.067975        0.477598
# 2042  120.0     852          2.0 -1.590376   -0.167041        1.423335
# 2043  120.0     858          5.0  1.409624    0.286580        1.123044
# 2044  120.0    1073          2.0 -1.590376   -0.050177        1.540200
# 2045  120.0    1210          5.0  1.409624    0.125830        1.283794
# 2046  120.0    1367          4.0  0.409624    0.043020        0.366604
#
# [2047 rows x 6 columns]

# %% [markdown]
# ## Making Predictions
#
# Predictions can be made from the model of the appropriate rating for a given user, $i$, for a given film, $j$, by simply taking the inner product between their vectors $\mathbf{u}_i$ and $\mathbf{v}_j$.

# %% [markdown]
# ### Assignment Question 6
#
# Create a function that provides the prediction of the ratings for the users in the dataset. Is the quality of the predictions affected by the number of iterations or the learning rate? The function should receive `Y`, `U` and `V` and return the predictions and the absolute error between the predictions and the actual rating given by the users. The predictions and the absolute error should be added as additional columns to the dataframe `Y`.
#
# *15 marks*

# %%
# Question 6 Code Answer
Length = len(Y['users'])
Y['Prediction'] = np.zeros(Length)
Y['Absolute error'] = np.zeros(Length)
def Predictions(Y,U,V):
    
    gU = pd.DataFrame(np.zeros((U.shape)), index=U.index)
    gV = pd.DataFrame(np.zeros((V.shape)), index=V.index)
    obj = 0.
    predictions = {}
    diffs = {}
    nrows = Y.shape[0]
    for i in range(nrows):
        row = Y.iloc[i] #Getting the user i
        user = row['users'] #Getting 'users' information
        film = row['movies'] #Getting 'movies' information
        rating = row['ratings'] #Getting 'ratings' information
        prediction = np.dot(U.loc[user], V.loc[film]) # U.V
        predictions[i] = prediction
        #print(U.loc[user])
        #print(V.loc[film])
        diff = prediction - rating # vTu - y
        diffs[i] = np.abs(diff)
        obj += diff*diff
        gU.loc[user] += 2*diff*V.loc[film]
        gV.loc[film] += 2*diff*U.loc[user]
    #print(diffs)
    return obj, gU, gV,list(predictions.values()),list(diffs.values())

iterations = 10
for i in range(iterations):
    obj, gU, gV,predictions,diffs = Predictions(Y, U, V)
    print("Iteration", i, "Objective function: ", obj)
    U -= learn_rate*g
# 2032  120.0     631          3.0 -0.590376   -0.061378        0.528999
# 2033  120.0     648          3.0 -0.590376   -0.102236        0.488140
# 2034  120.0     653          3.0 -0.590376   -0.218153        0.372223
# 2035  120.0     733          4.0  0.409624    0.032893        0.376731
# 2036  120.0     736          3.0 -0.590376   -0.066721        0.523655
# 2037  120.0     743          3.0 -0.590376   -0.131165        0.459211
# 2038  120.0     765          3.0 -0.590376   -0.061506        0.528870
# 2039  120.0     780          2.0 -1.590376   -0.058468        1.531908
# 2040  120.0     783          3.0 -0.590376   -0.024820        0.565556
# 2041  120.0     802          4.0  0.409624   -0.067975        0.477598
# 2042  120.0     852          2.0 -1.590376   -0.167041        1.423335
# 2043  120.0     858          5.0  1.409624    0.286580        1.123044
# 2044  120.0    1073          2.0 -1.590376   -0.050177        1.540200
# 2045  120.0    1210          5.0  1.409624    0.125830        1.283794
# 2046  120.0    1367          4.0  0.409624    0.043020        0.366604
#
# [2047 rows x 6 columns]

# %% [markdown]
# ##### Is the quality of the predictions affected by the number of iterations or the learning rate?
# Yes, more iterations make less prediction, and more learing rate makes more reducing rate of prediction.

# %%
np.absolute(-1)
# Out:
# 1

# %% [markdown]
# ## Stochastic Gradient Descent or Robbins Monroe Algorithm
#
# Stochastic gradient descent involves updating separating each gradient update according to each separate observation, rather than summing over them all. It is an approximate optimization method, but it has proven convergence under certain conditions and can be much faster in practice. It is used widely by internet companies for doing machine learning in practice. For example, Facebook's ad ranking algorithm uses stochastic gradient descent.

# %% [markdown]
# ### Assignment Question 7
#
# Create a stochastic gradient descent version of the algorithm. Monitor the objective function after every 1000 updates to ensure that it is decreasing. When you have finished, plot the movie map and the user map in two dimensions (you can use the columns of the matrices $\mathbf{U}$ for the user map and the columns of $\mathbf{V}$ for the movie map). Provide three observations about these maps.
#
# *25 marks*

# %%
# Question 7 Code Answer
# %matplotlib inline 
learn_rate = 0.01
import pylab as plt
U = pd.DataFrame(np.random.normal(size=(nUsersInExample, q))*0.001, index=my_batch_users) #users vector
V = pd.DataFrame(np.random.normal(size=(n_movies, q))*0.001, index=indexes_unique_movies) #movies vector

def Stochastic_gradient(Y, U, V,batch=50):
    gU = pd.DataFrame(np.zeros((U.shape)), index=U.index)
    gV = pd.DataFrame(np.zeros((V.shape)), index=V.index)
    obj = 0.
    sample = np.random.choice(len(Y),batch,replace=False)
    diff = {}
    nrows = Y.shape[0]
    for i in sample:
        row = Y.loc[i] #Getting the user i
        user = row['users'] #Getting 'users' information
        film = row['movies'] #Getting 'movies' information
        rating = row['ratings'] #Getting 'ratings' information
        prediction = np.dot(U.loc[user], V.loc[film]) # U.V
        diff = prediction - rating # v^Tu - y
        #obj += diff*diff
        #print("Old gU\n",gU)
        #print("Gradiant U at ",i," is ", 2*diff*V.loc[film])
        gU.loc[user] += 2*diff*V.loc[film]
        #print("New gU\n",2*diff*V.loc[film])
        gV.loc[film] += 2*diff*U.loc[user]
        #print(2*diff*U.loc[user])
    user = np.array(U)
    film = np.array(V)
    X = {}
    test = user.dot(film.T)
    
    U -= learn_rate*gU    
    V -= learn_rate*gV
    nrows = Y.shape[0]
        
    return obj, gU, gV,user,film

def check_obj(Y):
    nrows = Y.shape[0]
    obj = 0
    for i in range(nrows):
        row = Y.iloc[i] #Getting the user i
        user = row['users'] #Getting 'users' information
        film = row['movies'] #Getting 'movies' information
        rating = row['ratings'] #Getting 'ratings' information
        prediction = np.dot(U.loc[user], V.loc[film]) # U.V
        predictions[i] = prediction
        #print(U.loc[user])
        #print(V.loc[film])
        diff = prediction - rating # vTu - y
        #diffs[i] = np.abs(diff)
        obj += diff*diff
    return obj

Obj = {}
U_update ={}
V_update = {}
iterations = 10000
for i in range(iterations):

    obj, gU, gV,user,film = Stochastic_gradient(Y, U, V)
    #print("Old U",U)
    
    if i%1000 == 0:
        U_update[i] = U
        V_update[i] = V
        obj = check_obj(Y)
        print("Iteration", i, "Objective function: ", obj)
        Obj[i] = obj
# Out:
# Iteration 0 Objective function:  1903.280419145339
# Iteration 1000 Objective function:  725.8595775188253
# Iteration 2000 Objective function:  205.85468411691838
# Iteration 3000 Objective function:  160.83149780638
# Iteration 4000 Objective function:  150.2086000433601
# Iteration 5000 Objective function:  142.5312637320025
# Iteration 6000 Objective function:  137.53866043313096
# Iteration 7000 Objective function:  134.54284945192362
# Iteration 8000 Objective function:  137.5525707380174
# Iteration 9000 Objective function:  130.1029672428254

# %%
# Question 7 Code Answer
# (Continue)
#print(V_update)
plt.title('Objective result to each iteration')
plt.ylabel('Obj',rotation=0)
plt.xlabel('iterations')
plt.grid(True)

plt.plot(list(Obj.keys()), list(Obj.values()))
plt.show()

#print(U)
plt.title('User map')
plt.plot(U[0],U[1],'rx')
plt.text(-2,4,"Observation 1: There are 10  points of U as the output of spreading on the plot according to each vector in U")
plt.ylabel('U1',rotation=0)
plt.xlabel('U0',rotation=0)
plt.show()

plt.title('Movie map')
plt.plot(V[0],V[1],'rx')
plt.ylabel('V1',rotation=0)
plt.xlabel('V0',rotation=0)
plt.text(0,0,"Observation 2: There are 2046 points of U as the output of spreading on the plot according to each vector in V")
plt.show()
print("Observation 3: Most of points are near (0,0) because the random distribution is normal.")
#Sample_U = U.loc[my_batch_users[np.random.randint(len(U))]]#For random the piece of data in U to calculate gradiant
#print(Sample_U)
#Sample_V = V.loc[indexes_unique_movies[np.random.randint(len(V))]]#For random the piece of data in U to calculate gradiant
#print(Sample_V)
#print(np.dot(Sample_U.values,Sample_V.values))
#random_index_v

#print(Y)

#len(U)
# Out:
# Observation 3: Most of points are near (0,0) because the random distribution is normal.

# %% [markdown]
# ## Is Our Map Enough? Are Our Data Enough?
#
# Is two dimensions really enough to capture the complexity of humans and their artforms? Perhaps we need even more dimensions to capture that complexity. Extending our books analogy further, consider how we should place books that have a historical timeframe as well as some geographical location. Do we really want books from the 2nd World War to sit alongside books from the Roman Empire? Books on the American invasion of Sicily in 1943 are perhaps less related to books about Carthage than those that study the Jewish Revolt from 66-70 (in the Roman Province of Judaea). So books that relate to subjects which are closer in time should be stored together. However, a student of rebellion against empire may also be interested in the relationship between the Jewish Revolt of 66-70 and the Indian Rebellion of 1857, nearly 1800 years later. Whilst the technologies are different, the psychology of the people is shared: a rebellious nation angainst their imperial masters, triggered by misrule with a religious and cultural background. To capture such complexities we would need further dimensions in our latent representation. But are further dimensions justified by the amount of data we have? Can we really understand the facets of a film that only has at most three or four ratings?

# %% [markdown]
# ## Going Further
#
# If you want to take this model further then you'll need more data. You can use again the MovieLens 100k data but increasing the number of users (for example, for the Steepest Descent Algorithm you can do this by modifying the variable `nUsersInExample` that was set as 10 before).

# %% [markdown]
# ### Assignment Question 8
#
# Use stochastic gradient descent to make a movie map for the MovieLens 100k data. Plot the map of the movies when you are finished.
#
# *15 marks*

# %%
# Code for question 8 here.

ratings_new = pd.read_csv("./ml-latest-small/ratings.csv")
p_list_users = ratings['userId']
p_list_movies = ratings['movieId']
p_list_ratings_original = ratings['rating']
mean_ratings_train = np.mean(p_list_ratings_original)
p_list_ratings =  p_list_ratings_original - mean_ratings_train

Y_new = pd.DataFrame({'users': p_list_users, 
                  'movies': p_list_movies, 
                  'ratingsorig': p_list_ratings_original,
                  'ratings':p_list_ratings.tolist()})
number_of_users = len(p_list_users.unique())
number_of_movies = len(p_list_movies.unique())

#print(Y_new)
def check_obj_1(Y_new):
    nrows = Y_new.shape[0]
    obj = 0
    for i in range(nrows):
        row = Y_new.iloc[i] #Getting the user i
        user = row['users'] #Getting 'users' information
        film = row['movies'] #Getting 'movies' information
        rating = row['ratings'] #Getting 'ratings' information
        prediction = np.dot(U.loc[user], V.loc[film]) # U.V
        #predictions[i] = prediction
        #print(U.loc[user])
        #print(V.loc[film])
        diff = prediction - rating # vTu - y
        #diffs[i] = np.abs(diff)
        obj += diff*diff
    return obj

#print(Y_new)
def check_obj_2(Y_new):
    nrows = Y_new.shape[0]
    obj = 0    
    #Getting the user i
    user = Y_new['users'] #Getting 'users' information
    film = Y_new['movies'] #Getting 'movies' information
    
    rating = Y_new['ratings'] #Getting 'ratings' information
    prediction = np.dot(U, V.T) # U.V
    print(prediction.shape)
    #predictions[i] = prediction
    #print(U.loc[user])
    #print(V.loc[film])
    diff = prediction - rating # vTu - y
    #diffs[i] = np.abs(diff)
    obj += diff*diff
    return obj

U = pd.DataFrame(np.random.normal(size=(number_of_users, q))*0.001, index=p_list_users.unique()) #users vector
print(U)
V = pd.DataFrame(np.random.normal(size=(number_of_movies, q))*0.001, index=p_list_movies.unique()) #movies vector
Obj = {}
U_update ={}
V_update = {}

iterations = 10000
for i in range(iterations):

    obj, gU, gV,user,film = Stochastic_gradient(Y, U, V,batch=50)
    #print("Old U",U)
    
    if i%1000 == 0:
        U_update[i] = U
        V_update[i] = V
        obj = check_obj_1(Y_new)
        print("Iteration", i, "Objective function: ", obj)
        Obj[i] = obj

        

plt.title('Movie map')
plt.plot(V[0],V[1],'rx')
plt.ylabel('V1',rotation=0)
plt.xlabel('V0',rotation=0)
plt.show()


#p_list_ratings_original = p_list_ratings.tolist()
#mean_ratings_train = np.mean(p_list_ratings)
#p_list_ratings =  p_list_ratings - mean_ratings_train # remove the mean
#p_list_movies = np.concatenate(list_movies_each_user).ravel().tolist()
# Out:
#             0         1
# 1    0.002694 -0.000059
# 2   -0.000669 -0.000403
# 3    0.000251  0.000931
# 4    0.001797 -0.001228
# 5   -0.000083 -0.000671
# 6    0.000458  0.000870
# 7    0.001256  0.000180
# 8   -0.000805 -0.000750
# 9   -0.000192  0.000181
# 10   0.000884 -0.002163
# 11  -0.000837 -0.000631
# 12  -0.000215  0.000998
# 13   0.000660 -0.000697
# 14   0.001015  0.000945
# 15   0.000790 -0.000344
# 16   0.000637 -0.000690
# 17   0.001186 -0.000722
# 18   0.002252  0.002602
# 19   0.001170 -0.001054
# 20   0.000394  0.000364
# 21  -0.000852 -0.000485
# 22   0.001109  0.001806
# 23   0.000625 -0.000539
# 24  -0.000845 -0.000338
# 25  -0.000824  0.000542
# 26  -0.000656 -0.000267
# 27   0.002014 -0.000420
# 28  -0.000709  0.000602
# 29   0.000425  0.000442
# 30  -0.000281 -0.000035
# ..        ...       ...
# 581  0.001812  0.000646
# 582 -0.001521 -0.000004
# 583 -0.002117  0.000395
# 584 -0.000390 -0.000880
# 585  0.000387  0.000415
# 586  0.000633 -0.000860
# 587  0.000682  0.002445
# 588 -0.000426  0.000320
# 589 -0.001187  0.000576
# 590 -0.000501  0.001716
# 591 -0.000660  0.000803
# 592 -0.000874  0.001208
# 593 -0.000573 -0.000056
# 594 -0.002506 -0.000604
# 595  0.000470  0.001086
# 596  0.000374 -0.000249
# 597  0.000136 -0.000236
# 598 -0.001673  0.000485
# 599  0.002257 -0.001092
# 600  0.000816  0.000215
# 601  0.001095 -0.000382
# 602  0.000076  0.000215
# 603  0.000574 -0.001462
# 604 -0.002061 -0.000730
# 605  0.000263 -0.000476
# 606 -0.001923  0.001843
# 607 -0.000134  0.000033
# 608  0.000192 -0.000036
# 609  0.000355 -0.001305
# 610  0.000091  0.000683
#
# [610 rows x 2 columns]
# Iteration 0 Objective function:  109594.25629738002
# Iteration 1000 Objective function:  108504.22558835387
# Iteration 2000 Objective function:  107906.46198904037
# Iteration 3000 Objective function:  107860.8247139959
# Iteration 4000 Objective function:  107857.887919373
# Iteration 5000 Objective function:  107843.84578589954
# Iteration 6000 Objective function:  107842.78198689896
# Iteration 7000 Objective function:  107831.73308426767
# Iteration 8000 Objective function:  107832.82786179648
# Iteration 9000 Objective function:  107831.13080455663
